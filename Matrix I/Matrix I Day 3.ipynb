# %%
from google.colab import drive
import pandas as pd
import numpy as np

# %%
#!pip install datadotworld

# %%
#!pip install datadotworld[pandas]

# %%
#dw configure

# %%
import datadotworld as dw

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
cd "/content/drive"
# Out:
# /content/drive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd "My Drive/Colab Notebooks"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
ls
# Out:
# 'Ch 2 Day 5 cat&dogs.ipynb'
# 'Ch 3 Day 4.ipynb'
# 'cifar10 - Challenge 2 Day 4.ipynb'
# 'Copy of Ch 2 Day 5 cat&dogs.ipynb'
# 'Copy of Ch 3 Day 4.ipynb'
# 'Copy of cifar10 - Challenge 2 Day 4.ipynb'
# 'Copy of Copy of Ch 3 Day 4.ipynb'
#  data_workshop_matrix/

# %%
cd "data_workshop_matrix/"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_matrix

# %%
ls
# Out:
#  ColabDriveGithub.ipynb   Hello.ipynb   LICENSE  'Matrix I'/   README.md

# %%
cd "Matrix I"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_matrix/Matrix I

# %%
ls
# Out:
#  data/  'Matrix I Day 3.ipynb'

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()

# %%
df.shape
# Out:
# (19387, 48)

# %%
df.head()
# Out:
#                      id asins                brand  ...  vin websiteids  weight
# 0  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo  ...  NaN        NaN     NaN
# 1  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo  ...  NaN        NaN     NaN
# 2  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
# 3  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
# 4  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df['prices_currency'].unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df['prices_currency'].value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# PalmBeach Jewelry - Walmart.com                           3
# New with box                                              3
# new                                                       3
# UnbeatableSale.com, Inc. - Walmart.com                    3
# Wholesale Costume and Party Supplies - Walmart.com        2
# Shoes.com                                                 1
# SHOEBACCA LTD. - Walmart.com                              1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %%
df_usd = df[df['prices_currency']=='USD'].copy()

# %%
df_usd['prices_amountmin'] = df_usd['prices_amountmin'].astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
np.percentile(df_usd['prices_amountmin'], 99)
# Out:
# 895.0

# %%
df_usd_trimmed=df_usd[df_usd['prices_amountmin']<895]

# %%
df_usd_trimmed['prices_amountmin'].hist(bins=100)

# %%
ls
# Out:
#  data/  'Matrix I Day 3.ipynb'

# %%
# !git add 'Matrix I Day 3.ipynb'

# %%
# !git commit -m "Read Men's Shoes Prices dataset from data.world"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@2d6c5a3c1159.(none)')

# %%
# !git config --global user.email "andrzej.malina@gmail.com"
# !git config --global user.name "Andrzej Jankowski"

# %%
# !git push -u origin master
# Out:
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Everything up-to-date

# %%
ls
# Out:
#  data/  'Matrix I Day 3.ipynb'

# %%
cd 'data'
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_matrix/Matrix I/data

# %%
cd -
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_matrix/Matrix I/data

# %%
cd "/content/drive/My Drive/Colab Notebooks/data_workshop_matrix/Matrix I"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_matrix/Matrix I

# %%
data2 = dw.load_dataset('datafiniti/womens-shoe-prices')

# %%
data2.dataframes
# Out:
# LazyLoadedDict({'7003_1': LazyLoadedValue(<pandas.DataFrame>), 'datafiniti_womens_shoes': LazyLoadedValue(<pandas.DataFrame>), 'datafiniti_womens_shoes_jun19': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df2 = data2.dataframes['7003_1']

# %%
df2.shape
# Out:
# (19045, 47)

# %%
df2.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'websiteids', 'weight'],
#       dtype='object')

# %%
df2['prices_currency'].unique()
# Out:
# array(['USD', 'CAD', 'AUD', 'EUR', nan, 'GBP',
#        'Off Price Direct - Walmart.com', 'new'], dtype=object)

# %%
df2['prices_currency'].value_counts()
# Out:
# USD                               18199
# CAD                                 638
# AUD                                 118
# EUR                                  64
# GBP                                  15
# Off Price Direct - Walmart.com        1
# new                                   1
# Name: prices_currency, dtype: int64

# %%
df2_usd = df2[df2['prices_currency']=='USD'].copy()

# %%
df2_usd.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'websiteids', 'weight'],
#       dtype='object')

# %%
df2_usd['prices_amountmin'] = df2_usd['prices_amountmin'].astype(np.float)
df2_usd['prices_amountmin'].hist()

# %%
np.percentile(df2_usd['prices_amountmin'], 99)
# Out:
# 1100.0

# %%
df2_usd_trimmed=df_usd[df_usd['prices_amountmin']<1100]
df2_usd_trimmed['prices_amountmin'].hist(bins=100)

# %%
# !git add 'Matrix I Day 3.ipynb'
